# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

conn = psycopg2.connect(
    dbname="agro_db", user="postgres", password="postgres", host="localhost", port="5432"
)
data = pd.read_sql("SELECT * FROM sensor_data", conn)

# Basic stats
print(data.describe())

# Plot temperature trends
sns.lineplot(x='timestamp', y='temperature', data=data)
plt.title("Temperature Over Time")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hitansha pandey\AppData\Local\Temp\ipykernel_30744\67558511.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql("SELECT * FROM sensor_data", conn)
#             id                      timestamp  temperature   humidity  \
# count  8.00000                              8     8.000000   8.000000
# mean   4.50000  2025-07-05 02:17:14.639049728    29.207500  64.013750
# min    1.00000     2025-07-05 02:16:07.183325    20.400000  33.940000
# 25%    2.75000  2025-07-05 02:16:40.910314496    24.182500  49.997500
# 50%    4.50000  2025-07-05 02:17:14.658934528    27.910000  62.180000
# 75%    6.25000  2025-07-05 02:17:48.379009280    35.707500  82.280000
# max    8.00000     2025-07-05 02:18:22.046034    39.400000  88.720000
# std    2.44949                            NaN     7.267518  20.484514
#
#        soil_moisture        ph       light
# count       8.000000  8.000000    8.000000
# mean      419.308750  6.587500  530.202500
# min       272.340000  5.670000  319.350000
# 25%       311.102500  6.100000  445.617500
# 50%       383.935000  6.680000  510.050000
# 75%       495.672500  7.140000  619.510000
# max       648.000000  7.350000  763.020000
# std       142.207637  0.633195  157.310789

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

conn = psycopg2.connect(
    dbname="agro_db", user="postgres", password="postgres", host="localhost", port="5432"
)
data = pd.read_sql("SELECT * FROM sensor_data", conn)

# Basic stats
print(data.describe())

# Plot temperature trends
sns.lineplot(x='timestamp', y='temperature', data=data)
plt.title("Temperature Over Time")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hitansha pandey\AppData\Local\Temp\ipykernel_30744\67558511.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql("SELECT * FROM sensor_data", conn)
#             id                      timestamp  temperature   humidity  \
# count  8.00000                              8     8.000000   8.000000
# mean   4.50000  2025-07-05 02:17:14.639049728    29.207500  64.013750
# min    1.00000     2025-07-05 02:16:07.183325    20.400000  33.940000
# 25%    2.75000  2025-07-05 02:16:40.910314496    24.182500  49.997500
# 50%    4.50000  2025-07-05 02:17:14.658934528    27.910000  62.180000
# 75%    6.25000  2025-07-05 02:17:48.379009280    35.707500  82.280000
# max    8.00000     2025-07-05 02:18:22.046034    39.400000  88.720000
# std    2.44949                            NaN     7.267518  20.484514
#
#        soil_moisture        ph       light
# count       8.000000  8.000000    8.000000
# mean      419.308750  6.587500  530.202500
# min       272.340000  5.670000  319.350000
# 25%       311.102500  6.100000  445.617500
# 50%       383.935000  6.680000  510.050000
# 75%       495.672500  7.140000  619.510000
# max       648.000000  7.350000  763.020000
# std       142.207637  0.633195  157.310789

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

conn = psycopg2.connect(
    dbname="agro_db", user="postgres", password="postgres", host="localhost", port="5432"
)
data = pd.read_sql("SELECT * FROM sensor_data", conn)

# Basic stats
print(data.describe())

# Plot temperature trends
sns.lineplot(x='timestamp', y='temperature', data=data)
plt.title("Temperature Over Time")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hitansha pandey\AppData\Local\Temp\ipykernel_30744\67558511.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql("SELECT * FROM sensor_data", conn)
#             id                      timestamp  temperature   humidity  \
# count  8.00000                              8     8.000000   8.000000
# mean   4.50000  2025-07-05 02:17:14.639049728    29.207500  64.013750
# min    1.00000     2025-07-05 02:16:07.183325    20.400000  33.940000
# 25%    2.75000  2025-07-05 02:16:40.910314496    24.182500  49.997500
# 50%    4.50000  2025-07-05 02:17:14.658934528    27.910000  62.180000
# 75%    6.25000  2025-07-05 02:17:48.379009280    35.707500  82.280000
# max    8.00000     2025-07-05 02:18:22.046034    39.400000  88.720000
# std    2.44949                            NaN     7.267518  20.484514
#
#        soil_moisture        ph       light
# count       8.000000  8.000000    8.000000
# mean      419.308750  6.587500  530.202500
# min       272.340000  5.670000  319.350000
# 25%       311.102500  6.100000  445.617500
# 50%       383.935000  6.680000  510.050000
# 75%       495.672500  7.140000  619.510000
# max       648.000000  7.350000  763.020000
# std       142.207637  0.633195  157.310789

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

conn = psycopg2.connect(
    dbname="agro_db", user="postgres", password="postgres", host="localhost", port="5432"
)
data = pd.read_sql("SELECT * FROM sensor_data", conn)

# Basic stats
print(data.describe())

# Plot temperature trends
sns.lineplot(x='timestamp', y='temperature', data=data)
plt.title("Temperature Over Time")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hitansha pandey\AppData\Local\Temp\ipykernel_30744\67558511.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql("SELECT * FROM sensor_data", conn)
#             id                      timestamp  temperature   humidity  \
# count  8.00000                              8     8.000000   8.000000
# mean   4.50000  2025-07-05 02:17:14.639049728    29.207500  64.013750
# min    1.00000     2025-07-05 02:16:07.183325    20.400000  33.940000
# 25%    2.75000  2025-07-05 02:16:40.910314496    24.182500  49.997500
# 50%    4.50000  2025-07-05 02:17:14.658934528    27.910000  62.180000
# 75%    6.25000  2025-07-05 02:17:48.379009280    35.707500  82.280000
# max    8.00000     2025-07-05 02:18:22.046034    39.400000  88.720000
# std    2.44949                            NaN     7.267518  20.484514
#
#        soil_moisture        ph       light
# count       8.000000  8.000000    8.000000
# mean      419.308750  6.587500  530.202500
# min       272.340000  5.670000  319.350000
# 25%       311.102500  6.100000  445.617500
# 50%       383.935000  6.680000  510.050000
# 75%       495.672500  7.140000  619.510000
# max       648.000000  7.350000  763.020000
# std       142.207637  0.633195  157.310789
